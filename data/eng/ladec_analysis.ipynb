# %%
import pandas as pd

df = pd.read_csv('LADECv1-2019.csv')
df
# Out:
#       id_master     c1     c2        stim  obs  obsc1  obsc2  stimlen  c1len  \
# 0          3237    gad  about    gadabout    1      4      3        8      3
# 1          4592  knock  about  knockabout    1      3      4       10      5
# 2          8231   turn  about   turnabout    1     19      7        9      4
# 3          6139   race  about   raceabout    1      4      1        9      4
# 4          8331   walk  about   walkabout    1      2      5        9      4
# ...         ...    ...    ...         ...  ...    ...    ...      ...    ...
# 8951       4515   junk  yards   junkyards    1      1     10        9      4
# 8952       6812   ship  yards   shipyards    1     10      9        9      4
# 8953       2667   farm  yards   farmyards    1     10      6        9      4
# 8954       1007  brick  yards  brickyards    1      8     12       10      5
# 8955       8892    zig    zag      zigzag    1      1      1        6      3
#
# ...

# %%
df.columns
# Out:
# Index(['id_master', 'c1', 'c2', 'stim', 'obs', 'obsc1', 'obsc2', 'stimlen',
#        'c1len', 'c2len', 'nparses', 'correctParse', 'ratingcmp', 'ratingC1',
#        'ratingC2', 'isPlural', 'nc1_cmp', 'nc2_cmp', 'nc1_cmpnoplural',
#        'nc2_cmpnoplural', 'sentiment_stim', 'sentiment_c1', 'sentiment_c2',
#        'sentimentprobpos_stim', 'sentimentprobpos_c1', 'sentimentprobpos_c2',
#        'sentimentprobneg_stim', 'sentimentprobneg_c1', 'sentimentprobneg_c2',
#        'sentimentratioposneg_stim', 'sentimentratioposneg_c1',
#        'sentimentratioposneg_c2', 'profanity_stim', 'profanity_c1',
#        'profanity_c2', 'isCommonstim', 'isCommonC1', 'isCommonC2',
#        'bg_boundary', 'bgJonesMewhort', 'bgSUBTLEX', 'bgFacebook', 'inSUBTLEX',
#        'inBLP', 'inELP', 'inJuhaszLaiWoodcock', 'c1_inELP', 'c1_inBrysbaert',
#        'c1_inWordnet', 'c1_inMMA', 'c2_inELP', 'c2_inBrysbaert',
#        'c2_inWordnet', 'c2_inMMA', 'LSAc1c2', 'LSAc1stim', 'LSAc2stim',
# ...

# %%
df['isPlural'].value_counts()
# Out:
# 0    6017
# 1    2939
# Name: isPlural, dtype: int64

# %%
df_singular = df[df['isPlural'] == 0]
df_singular.sort_values(by='stim_SLlg10wf', ascending=False)[['stim', 'stim_SLlg10wf', 'BLPbncfrequencymillion', 'fbusfreq', 'fbukfreq']].head(10)
# Out:
#             stim  stim_SLlg10wf  BLPbncfrequencymillion  fbusfreq   fbukfreq
# 5324     someone         4.3570              186.810000  763494.3   641109.6
# 979     somebody         4.2448                     NaN  168947.0    47586.5
# 1437     goodbye         3.7740               14.880000   32904.2    50281.4
# 8372   somewhere         3.7550               70.260002   59616.3    64377.2
# 2024    birthday         3.6954               32.470001  745402.4  1264823.8
# 5248   afternoon         3.6690                     NaN   92146.9   233438.4
# 2783  girlfriend         3.5891               11.740000   68411.1    72770.0
# 2784   boyfriend         3.5664               10.930000   83853.7    78783.8
# 3316    bullshit         3.5488                1.480000   83515.7    38659.6
# 6614    bullshit         3.5488                1.480000   83515.7    38659.6

# %%
in_corpus_columns = [col for col in df_singular.columns if col.startswith('in')]
in_corpus_columns
# Out:
# ['inSUBTLEX', 'inBLP', 'inELP', 'inJuhaszLaiWoodcock']

# %%
df_singular[in_corpus_columns].describe()
# Out:
#          inSUBTLEX        inBLP        inELP  inJuhaszLaiWoodcock
# count  6017.000000  6017.000000  6017.000000          6017.000000
# mean      0.584344     0.280705     0.435765             0.083430
# std       0.492876     0.449381     0.495898             0.276554
# min       0.000000     0.000000     0.000000             0.000000
# 25%       0.000000     0.000000     0.000000             0.000000
# 50%       1.000000     0.000000     0.000000             0.000000
# 75%       1.000000     1.000000     1.000000             0.000000
# max       1.000000     1.000000     1.000000             1.000000

# %%
# There are some duplicates in the data (eg bullshit = bull + shit, or bullshit = bulls + hit)
# Display compounds with the same name
df_duplicated = df_singular[df_singular.duplicated(subset=['stim'], keep=False)].sort_values('stim')
df_duplicated
# Out:
#       id_master       c1       c2        stim  obs  obsc1  obsc2  stimlen  \
# 3319         23   afters     hock  aftershock    2      3      3       10
# 6615         22    after    shock  aftershock    1      1      2       10
# 1932         44      air  crewman  aircrewman    2     58      1       10
# 4708         45  aircrew      man  aircrewman    1      1     32       10
# 1926         83     airs     crew    airscrew    1      2      1        8
# ...         ...      ...      ...         ...  ...    ...    ...      ...
# 6906       8835     work    space   workspace    2     45      6        9
# 7618       8876    yards     tick   yardstick    1      1      8        9
# 7115       8877     yard    stick   yardstick    2     12     19        9
# 5896       8897     zoos     pore    zoospore    1      1      2        8
# 6956       8898      zoo    spore    zoospore    2      8      3        8
#
#       c1len  c2len  ...  Juhasz_tran st_c1_mean  st_c2_mean  Zipfvalue  \
# ...

# %%
df_duplicated[df_duplicated['correctParse'] == "yes"]
# Out:
#       id_master       c1       c2        stim  obs  obsc1  obsc2  stimlen  \
# 6615         22    after    shock  aftershock    1      1      2       10
# 1932         44      air  crewman  aircrewman    2     58      1       10
# 4708         45  aircrew      man  aircrewman    1      1     32       10
# 6412         84      air    screw    airscrew    2     60      2        8
# 6595         85      air     ship     airship    1     31    115        7
# ...         ...      ...      ...         ...  ...    ...    ...      ...
# 6408       8769     wood    screw   woodscrew    2     42      4        9
# 6643       8832     work     shop    workshop    1     34      6        8
# 6906       8835     work    space   workspace    2     45      6        9
# 7115       8877     yard    stick   yardstick    2     12     19        9
# 6956       8898      zoo    spore    zoospore    2      8      3        8
#
#       c1len  c2len  ...  Juhasz_tran st_c1_mean  st_c2_mean  Zipfvalue  \
# ...

# %%
df_singular_correct = df_singular[df_singular['correctParse'] == "yes"]
len(df_singular_correct)
# Out:
# 5625

# %%
df_singular_correct["inSUBTLEX"].sum()
# Out:
# 3276
