# %%
import pandas as pd

# %%
df = pd.read_csv('../assets/final_compounds.csv', keep_default_na=False)
# Replace empty values in frequency_class column with nan
df['frequency_class'] = df['frequency_class'].replace('', 'nan')
df.head()
# Out:
#      compound modifier     head frequency_class
# 0  Aalbestand      Aal  Bestand            22.0
# 1     Aalfang      Aal     Fang            20.0
# 2    Aalfisch      Aal    Fisch             nan
# 3   Aalmutter      Aal   Mutter             nan
# 4    Aalraupe      Aal    Raupe             nan

# %% [markdown]
# # Game Mode: **All in One** - Build big compounds

# %%
# Add a column "level" to the dataframe, which is initiated with 0
df = df.assign(level=0)

# If the modifier of a compound is also a compound, increase the level of the compound by 1
df_modifier_is_compound = df.loc[df['modifier'].isin(df['compound']), 'level']
df.loc[df_modifier_is_compound.index, 'level'] = df.loc[df_modifier_is_compound.index, 'level'] + 1

# Do the same for the head of a compound
df_head_is_compound = df.loc[df['head'].isin(df['compound']), 'level']
df.loc[df_head_is_compound.index, 'level'] = df.loc[df_head_is_compound.index, 'level'] + 1

# Show a summary of the dataframe
print(df.describe(include='all'))
df['level'].value_counts()
# Out:
#         compound modifier    head frequency_class          level
# count     113063   113063  113063          113063  113063.000000
# unique    113041    11859    9678              21            NaN
# top     Andenken     Land    Zeit             nan            NaN
# freq           2      464     438           21234            NaN
# mean         NaN      NaN     NaN             NaN       0.148484
# std          NaN      NaN     NaN             NaN       0.369247
# min          NaN      NaN     NaN             NaN       0.000000
# 25%          NaN      NaN     NaN             NaN       0.000000
# 50%          NaN      NaN     NaN             NaN       0.000000
# 75%          NaN      NaN     NaN             NaN       0.000000
# max          NaN      NaN     NaN             NaN       2.000000
# 0    96835
# 1    15668
# 2      560
# Name: level, dtype: int64

# %%
def increase_level(df, level):
    df_level = df.loc[df['level'] >= level]
    level_as_modifier_or_head = df['modifier'].isin(df_level['compound']) | df['head'].isin(df_level['compound'])
    df.loc[level_as_modifier_or_head, 'level'] = df.loc[level_as_modifier_or_head, 'level'] + 1
    return df

df = increase_level(df, 1)
df = increase_level(df, 2)
df = increase_level(df, 3)
df = increase_level(df, 4)
df = increase_level(df, 5)

df['level'].value_counts()
# Out:
# 0    96835
# 1    15342
# 2      864
# 3       22
# Name: level, dtype: int64

# %%
# Print the rows with level 3
df.loc[df['level'] == 3]
# Out:
#                                compound            modifier  \
# 11683             Biomasseheizkraftwerk            Biomasse
# 13374          Brennstoffzellenfahrzeug     Brennstoffzelle
# 14249        Bundesligatorschützenkönig          Bundesliga
# 23683          Fachhochschulstudiengang      Fachhochschule
# 24227        Fahrzeuginnenraumreinigung   Fahrzeuginnenraum
# 26339         Feuerwehrdienstvorschrift           Feuerwehr
# 28045       Fluorchlorkohlenwasserstoff               Fluor
# 29064           Frauenfußballbundesliga       Frauenfußball
# 29088  Frauenhandballnationalmannschaft                Frau
# 41609          Hochwasserschutzmaßnahme    Hochwasserschutz
# 42969        Hörgeräteakustikerhandwerk  Hörgeräteakustiker
# 49707        Kohlefaserverbundwerkstoff          Kohlefaser
# 51362             Kraftfahrzeughandwerk       Kraftfahrzeug
# 51366          Kraftfahrzeugkennzeichen       Kraftfahrzeug
# 60816          Mehrwertdiensterufnummer      Mehrwertdienst
# 64368  Männerhandballnationalmannschaft                Mann
# 67654        Oberbürgermeisterwahlkampf   Oberbürgermeister
# 79111     Rundfunkgebührenstaatsvertrag      Rundfunkgebühr
# 91118            Steinbildhauerhandwerk      Steinbildhauer
# 95508      Teledienstedatenschutzgesetz          Teledienst
# 99331              Umweltschutzmaßnahme        Umweltschutz
# 99338            Umweltschutzvorschrift        Umweltschutz
#
#                              head frequency_class  level
# 11683               Heizkraftwerk             nan      3
# 13374                    Fahrzeug            21.0      3
# 14249            Torschützenkönig             nan      3
# 23683                 Studiengang            20.0      3
# 24227                   Reinigung             nan      3
# 26339            Dienstvorschrift             nan      3
# 28045      Chlorkohlenwasserstoff            18.0      3
# 29064                  Bundesliga             nan      3
# 29088  Handballnationalmannschaft             nan      3
# 41609                    Maßnahme            18.0      3
# 42969                    Handwerk             nan      3
# 49707            Verbundwerkstoff             nan      3
# 51362                    Handwerk            21.0      3
# 51366                 Kennzeichen            22.0      3
# 60816                   Rufnummer             nan      3
# 64368  Handballnationalmannschaft             nan      3
# 67654                   Wahlkampf            21.0      3
# 79111               Staatsvertrag             nan      3
# 91118                    Handwerk             nan      3
# 95508           Datenschutzgesetz             nan      3
# 99331                    Maßnahme            18.0      3
# 99338                  Vorschrift            21.0      3

# %%
# Show the rows with level >= 2 and sort them by frequency_class, ignoring null values
df.loc[df['level'] >= 2].sort_values(by='frequency_class', na_position='first').head(20)
# Out:
#                         compound        modifier               head  \
# 26347        Feuerwehrgerätehaus       Feuerwehr         Gerätehaus
# 14383       Bundesumweltminister            Bund     Umweltminister
# 87239          Sonntagnachmittag         Sonntag         Nachmittag
# 103879         Vorjahreszeitraum         Vorjahr           Zeitraum
# 14384    Bundesumweltministerium            Bund  Umweltministerium
# 6810            Bahnhofsvorplatz         Bahnhof           Vorplatz
# 51965       Kreisvolkshochschule           Kreis    Volkshochschule
# 99332   Umweltschutzorganisation    Umweltschutz       Organisation
# 99222            Umweltbundesamt          Umwelt          Bundesamt
# 14372        Bundestagswahlkampf       Bundestag          Wahlkampf
# 29373          Freitagnachmittag         Freitag         Nachmittag
# 60818     Mehrwertsteuererhöhung  Mehrwertsteuer           Erhöhung
# 94647          Tanklöschfahrzeug            Tank      Löschfahrzeug
# 36596           Großbildleinwand        Großbild           Leinwand
# 60819         Mehrwertsteuersatz  Mehrwertsteuer               Satz
# 4531      Atomwaffensperrvertrag       Atomwaffe       Sperrvertrag
# 4833       Aufsichtsratsmitglied    Aufsichtsrat           Mitglied
# 90719            Standortvorteil        Standort            Vorteil
# 90167          Stadtratsmitglied        Stadtrat           Mitglied
# 87274           Sonntagvormittag         Sonntag          Vormittag
#
#        frequency_class  level
# 26347             14.0      2
# 14383             14.0      2
# 87239             14.0      2
# 103879            14.0      2
# 14384             15.0      2
# 6810              15.0      2
# 51965             15.0      2
# 99332             15.0      2
# 99222             15.0      2
# 14372             15.0      2
# 29373             15.0      2
# 60818             15.0      2
# 94647             16.0      2
# 36596             16.0      2
# 60819             16.0      2
# 4531              16.0      2
# 4833              16.0      2
# 90719             16.0      2
# 90167             16.0      2
# 87274             16.0      2
